# %%
import pandas as pd
from tqdm import trange, tqdm

# %% [markdown]
# импортируем библиотеки

# %%
df = pd.read_csv('csv\hi_tech_8_5_2024.csv')

# %% [markdown]
# загружаем файл

# %%
df
# Out:
#                                               soup_name           id  \
# 0     https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088228
# 1     https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088229
# 2     https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088221
# 3     https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088222
# 4     https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088230
# ...                                                 ...          ...
# 5899  https://hi-tech.md/kompyuternaya-tehnika/tovar...  Т-000089380
# 5900  https://hi-tech.md/kompyuternaya-tehnika/tovar...  Т-000089357
# 5901  https://hi-tech.md/kompyuternaya-tehnika/tovar...  Т-000089359
# 5902  https://hi-tech.md/kompyuternaya-tehnika/tovar...  Т-000089360
# 5903  https://hi-tech.md/kompyuternaya-tehnika/tovar...  Т-000089356
#
#             date availability  \
# 0     2024-05-08    В наличии
# 1     2024-05-08    В наличии
# 2     2024-05-08    В наличии
# 3     2024-05-08    В наличии
# 4     2024-05-08    В наличии
# ...          ...          ...
# 5899  2024-05-08    Предзаказ
# 5900  2024-05-08    Предзаказ
# 5901  2024-05-08    Предзаказ
# 5902  2024-05-08    Предзаказ
# 5903  2024-05-08    Предзаказ
#
#                                                   title    price  old_price
# 0                   Батарейка Energenie EG-BA-CR1220-01      4.0        NaN
# 1                   Батарейка Energenie EG-BA-CR2016-01      4.0        NaN
# 2                      Батарейка Energenie EG-BA-AA4-01      5.0        NaN
# 3                     Батарейка Energenie EG-BA-AAA4-01      5.0        NaN
# 4                   Батарейка Energenie EG-BA-CR2025-01      5.0        NaN
# ...                                                 ...      ...        ...
# 5899      Моноблок Apple iMac 24" 2023 Blue (MQRR3RU/A)  34799.0    38799.0
# 5900  Ноутбук Apple MacBook PRO 14.2" 2023 Silver (M...  35399.0        NaN
# 5901  Ноутбук Apple MacBook PRO 14.2" 2023 Silver (M...  39399.0        NaN
# 5902  Ноутбук Apple MacBook PRO 14.2" 2023 Space Gre...  39399.0        NaN
# 5903  Ноутбук Apple MacBook PRO 14.2" 2023 Silver (M...  69599.0        NaN
#
# [5904 rows x 7 columns]

# %%
def category(x):
    xx = x.split('/')
    xx = xx[3]
    return xx

# %%
def subcategory(x):
    xx = x.split('/')
    xx = xx[4]
    return xx

# %%
def subgroup(x):
    xx = x.split('/')
    xx = xx[-3]
    return xx

# %%
def group(x):
    xx = x.split('/')
    if len(xx) == 7:
        return xx[-3]
    elif len(xx) == 8:
        return xx[-3]
    elif len(xx) == 9:
        return xx[-4]
    elif len(xx) == 10:
        return xx[-5]
    elif len(xx) == 11:
        return xx[-6]

# %% [markdown]
# создаем вспомогательные функции

# %%
df['action_sale'] = 0

# %%
df.loc[df['old_price'] > 0,'action_sale'] = 1

# %% [markdown]
# создаем столбец который показывает является ли товар акционным(1 - акционный, 0 - не акционный)

# %%
df['sale'] = (100 - ((df['price']*100)/df['old_price'])).round(2)

# %% [markdown]
# создаем столбец показывающий скидку в процентах

# %%
df['category'] = df['soup_name'].apply(category)

# %% [markdown]
# Создаем столбец показывающий категорию товаров

# %%
df['subcategory'] = df['soup_name'].apply(subcategory)

# %% [markdown]
# создаем столбец показывающий подкатегорию товаров

# %%
df['group'] = df['soup_name'].apply(group)

# %% [markdown]
# создаем столбец показывающий группу товаров

# %%
#df['subgroup'] = df['soup_name'].apply(subgroup)

# %%
df.loc[df['subcategory']=='monitory','group'] = 'monitory'

# %% [markdown]
# в подкатегории мониторы меняем названия групп на мониторы

# %%
df.head()
# Out:
#                                            soup_name           id        date  \
# 0  https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088228  2024-05-08
# 1  https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088229  2024-05-08
# 2  https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088221  2024-05-08
# 3  https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088222  2024-05-08
# 4  https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088230  2024-05-08
#
#   availability                                title  price  old_price  \
# 0    В наличии  Батарейка Energenie EG-BA-CR1220-01    4.0        NaN
# 1    В наличии  Батарейка Energenie EG-BA-CR2016-01    4.0        NaN
# 2    В наличии     Батарейка Energenie EG-BA-AA4-01    5.0        NaN
# 3    В наличии    Батарейка Energenie EG-BA-AAA4-01    5.0        NaN
# 4    В наличии  Батарейка Energenie EG-BA-CR2025-01    5.0        NaN
#
#    action_sale  sale                  category  \
# 0            0   NaN  televizory-i-elektronika
# 1            0   NaN  televizory-i-elektronika
# 2            0   NaN  televizory-i-elektronika
# 3            0   NaN  televizory-i-elektronika
# 4            0   NaN  televizory-i-elektronika
#
#                         subcategory                             group
# 0  batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 1  batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 2  batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 3  batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 4  batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva

# %%
df['category'].unique()
# Out:
# array(['televizory-i-elektronika', 'kompyuternaya-tehnika',
#        'diskont-ne-deystvuet-ru', 'bytovaya-tehnika', 'tovar-po-akcii',
#        'instrumenty-i-oborudovanie'], dtype=object)

# %%
df['subcategory'].unique()
# Out:
# array(['batareyki-i-zaryadnye-ustroystva', 'audiotehnika',
#        'smartfony-i-aksessuary', 'multimedia',
#        'nastennye-krepleniya-dlya-tv', 'pristavki-dlya-tv', 'gadzhety',
#        'telefony-dect-i-provodnye', 'tovary-apple', 'sport-i-otdyh',
#        'hd-cvi-videokamera-dahua-dh-hac-hdw1220mp-0280b-s2',
#        'umnyy-dom-s-yandeks', 'televizory', 'pylesosy-i-aksessuary',
#        'tehnika-karcher', 'aksessuary-dlya-melkoy-bytovoy-tehniki',
#        'tovary-dlya-uhoda-za-odezhdoy', 'minimoyki',
#        'prigotovlenie-napitkov', 'melkaya-tehnika-dlya-kuhni',
#        'stiralnye-i-sushilnye-mashiny', 'tehnika-dlya-krasoty',
#        'krupnaya-tehnika-dlya-kuhni', 'klimaticheskaya-tehnika',
#        'ustanovka-bytovoy-tehniki', 'prigotovlenie-pischi',
#        'tehnika-dlya-zdorovya', 'teploventilyator-tesy-hl-213v',
#        'elektroplita-zilan-zln8092', 'tekhnika-dlya-doma',
#        'kolpachok-rj-45-gembird-bt5bk-5', 'nakopiteli',
#        'konnektor-rj-45-gembird-cat5e-lc-8p8c-001',
#        'setevoe-oborudovanie', 'aksessuary', 'rashodnye-materialy',
#        'periferiynye-ustroystva', 'orgtehnika', 'komplektuyuschie',
#        'krepleniya-dlya-monitora', 'elektropitanie',
#        'konnektor-rj-45-gembird-cat5e-lc-8p8c-001-100',
#        'rul-sven-gc-w300', 'xbox-playstation', 'rul-sven-gc-w800-usb',
#        'noutbuki-planshety...', 'monitory', 'proektory-i-ekrany',
#        'processor-intel-core-i5-12400-box',
#        'processor-amd-ryzen-r7-5800x-box'], dtype=object)

# %%
df.group.unique()
# Out:
# array(['batareyki-i-zaryadnye-ustroystva', 'mikrofony', 'naushniki',
#        'aksessuary', 'smartfony-i-aksessuary',
#        'nastennye-krepleniya-dlya-tv', 'akusticheskie-sistemy',
#        'pristavki-dlya-tv', 'akustika', 'muzykalnaya-tehnika',
#        'upravlenie-elektropriborami', 'radio', 'pleery',
#        'telefony-dect-i-provodnye', 'saundbary', 'airpods',
#        'smart-gadzhety', 'hd-cvi-kamery', None, 'yandeks-stancii',
#        'televizory', 'smartfony', 'homepod', 'apple-whatch', 'iphone',
#        'filtry-i-meshki-dlya-pyli', 'meshki-i-filtry-karcher',
#        'aksessuary-k-pylesosam', 'aksessuary-dlya-zubnyh-schetok',
#        'mashinki-dlya-udaleniya-katyshkov', 'minimoyki',
#        'gladilnye-doski', 'sushilki-dlya-belya', 'turki-elektricheskie',
#        'vakuumatory', 'frontalnye-stiralnye-mashiny', 'kofevarki',
#        'vesy-napolnye', 'kofe', 'miksery', 'vytyazhki',
#        'plity-gazovye-i-elektricheskie', 'feny-dlya-volos',
#        'elektricheskie-chayniki', 'vesy-kuhonnye',
#        'vypryamiteli-dlya-volos', 'varochnye-poverhnosti', 'ployki',
#        'kronshteyny-dlya-mikrovolnovyh-pechey', 'tostery', 'kofemolki',
#        'obogrevateli', 'sokovyzhimalki', 'blendery',
#        'ustanovka-bytovoy-tehniki',
#        'komplektuyuschie-dlya-klimaticheskoy-tehniki',
#        'trimmery-mashinki-dlya-strizhki', 'ventilyatory', 'yogurtnicy',
#        'utyugi', 'kofemashiny', 'elektricheskie-zubnye-schetki',
#        'elektrogrili', 'sendvichnicy-i-vafelnicy',
#        'aksessuary-dlya-elektricheskih-britv', 'uvlazhniteli-kompleksy',
#        'massazhery-vannochki-dlya-nog', 'medicinskie-pribory',
#        'otparivateli-dlya-odezhdy', 'elektricheskie-britvy',
#        'nabory-dlya-ukladki-volos', 'pylesosy', 'choppery', 'boylery',
#        'kondicionery', 'elektromyasorubki', 'epilyatory',
#        'kuhonnye-kombayny', 'sushilki-dlya-fruktov',
#        'frityurnicy-i-aerogrili', 'elektro-pechi-i-duhovki', 'parovarki',
#        'irrigatory', 'holodilniki', 'multivarki', 'mikrovolnovye-pechi',
#        'parogeneratory', 'lomterezki', 'stiralnye-i-sushilnye-mashiny',
#        'poluavtomaticheskie-stiralnye-mashiny', 'hlebopechi', 'termopoty',
#        'generatory-lda', 'multivarki-skorovarki', 'shveynye-mashiny',
#        'morozilniki-i-lari', 'duhovye-shkafy', 'posudomoechnye-mashiny',
#        'vertikalnye-stiralnye-mashiny', 'otopitelnye-pechi',
#        'sushilnye-mashiny', 'stiralno-sushilnye-mashiny', 'kotly-gazovye',
#        'kondicionery-kassetnye', 'promyshlennye-kondicionery',
#        'diski-cd-dvd', 'rozetki-konnektory', 'patch-kordy',
#        'kabeli-i-perehodniki', 'zipy', 'bumaga', 'kovriki-dlya-myshi',
#        'dlya-noutbukov', 'kabeli-dlya-printerov', 'styazhki',
#        'termopasta', 'sistemy-ohlazhdeniya', 'kardridery', 'chernila',
#        'krepleniya-dlya-monitora', 'myshi', 'chistyaschie-sredstva',
#        'zaryadnye-usb', 'dzhoystiki-i-ruli', 'dlya-planshetov',
#        'zvukovye-karty', 'karty-pamyati', 'fleshki', 'adaptery',
#        'setevye-filtry', 'karmany-dlya-hdd-ssd', 'klaviatury-i-komplekty',
#        'karty-setevye', 'toner', 'instrument', 'kommutatory',
#        'veb-kamery', 'batarei', 'portativnye-akkumulyatory',
#        'povtoriteli-wifi', 'opticheskie-privody', 'moduli-pamyati',
#        'tochki-dostupa', 'bloki-pitaniya-dlya-noutbukov',
#        'bloki-pitaniya', 'kartridzhi', 'invertory', 'videoregistratory',
#        'nakopitel-ssd', 'korpusa', 'stabilizatory', 'nakopitel-hdd',
#        'printery-i-mfu', 'skanery', 'ibp', 'ruli', 'processory',
#        'vneshnie-hdd', 'unichtozhiteli-dokumentov', 'geympady-ps4-hbox',
#        'materinskie-platy', 'videokarty', 'planshetnye-pk', 'monitory',
#        'ekrany-dlya-proektorov', 'kabel-setevoy', 'setevye-shkafy',
#        'elektronnye-knigi', 'nettopy', 'sistemnye-bloki', 'noutbuki',
#        'pristavki-ps4-xbox', 'ipad', 'proektory', 'macbook', 'imac'],
#       dtype=object)

# %% [markdown]
# проссматриваем названия категорий подкатегорий и групп товаров

# %%
df[df['subcategory']=='tovary-apple'].groupby('group').agg({'price':('max','min','mean','median')})
# Out:
#                 price
#                   max      min          mean   median
# group
# airpods       10999.0    499.0   7661.500000  10999.0
# aksessuary      699.0    699.0    699.000000    699.0
# apple-whatch  17999.0   5749.0  10384.849057   9099.0
# homepod        2599.0   2599.0   2599.000000   2599.0
# imac          34799.0  26699.0  30749.000000  30749.0
# ipad          25649.0   6699.0  14639.500000  13424.0
# iphone        34899.0   9449.0  19246.692308  18489.0
# macbook       69599.0  21589.0  32192.076923  30599.0

# %%
def count_group(x):
    return df[df['group']==x]['id'].count()

# %%
df['count_group'] = df['group'].apply(count_group)

# %% [markdown]
# создание столбца с количеством товара в группе

# %%
def count_group_presence(x):
    return df[(df['availability']=='В наличии')&(df['group']==x)]['id'].count()

# %%
df['count_group_presence'] = df['group'].apply(count_group_presence)

# %% [markdown]
# создание столбца с количеством товара, который есть в наличии, в группе

# %%
def dif_price(x):    
    max_price = df[(df['availability']=='В наличии')&(df['group']==x)]['price'].max()
    min_price = df[(df['availability']=='В наличии')&(df['group']==x)]['price'].min() 
    return max_price / min_price

# %%
df['dif_price'] = df['group'].apply(dif_price)

# %%
df.head()
# Out:
#                                            soup_name           id        date  \
# 0  https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088228  2024-05-08
# 1  https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088229  2024-05-08
# 2  https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088221  2024-05-08
# 3  https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088222  2024-05-08
# 4  https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088230  2024-05-08
#
#   availability                                title  price  old_price  \
# 0    В наличии  Батарейка Energenie EG-BA-CR1220-01    4.0        NaN
# 1    В наличии  Батарейка Energenie EG-BA-CR2016-01    4.0        NaN
# 2    В наличии     Батарейка Energenie EG-BA-AA4-01    5.0        NaN
# 3    В наличии    Батарейка Energenie EG-BA-AAA4-01    5.0        NaN
# 4    В наличии  Батарейка Energenie EG-BA-CR2025-01    5.0        NaN
#
#    action_sale  sale                  category  \
# 0            0   NaN  televizory-i-elektronika
# 1            0   NaN  televizory-i-elektronika
# 2            0   NaN  televizory-i-elektronika
# 3            0   NaN  televizory-i-elektronika
# 4            0   NaN  televizory-i-elektronika
#
#                         subcategory                             group  \
# 0  batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 1  batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 2  batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 3  batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 4  batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
#
#    count_group  count_group_presence  dif_price
# 0           78                    77     199.75
# 1           78                    77     199.75
# 2           78                    77     199.75
# 3           78                    77     199.75
# 4           78                    77     199.75

# %%
df[(df['count_group_presence']>10)&(df['dif_price']>5)]
# Out:
#                                               soup_name           id  \
# 0     https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088228
# 1     https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088229
# 2     https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088221
# 3     https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088222
# 4     https://hi-tech.md/televizory-i-elektronika/ba...  Т-000088230
# ...                                                 ...          ...
# 5868  https://hi-tech.md/kompyuternaya-tehnika/noutb...  Т-000092563
# 5888  https://hi-tech.md/kompyuternaya-tehnika/noutb...  Т-000092562
# 5891  https://hi-tech.md/kompyuternaya-tehnika/noutb...  Т-000088960
# 5893  https://hi-tech.md/kompyuternaya-tehnika/noutb...  Т-000092559
# 5895  https://hi-tech.md/kompyuternaya-tehnika/noutb...  Т-000092564
#
#             date availability  \
# 0     2024-05-08    В наличии
# 1     2024-05-08    В наличии
# 2     2024-05-08    В наличии
# 3     2024-05-08    В наличии
# 4     2024-05-08    В наличии
# ...          ...          ...
# 5868  2024-05-08    Предзаказ
# 5888  2024-05-08    Предзаказ
# 5891  2024-05-08    В наличии
# 5893  2024-05-08    Предзаказ
# 5895  2024-05-08    Предзаказ
#
#                                                   title    price  old_price  \
# 0                   Батарейка Energenie EG-BA-CR1220-01      4.0        NaN
# 1                   Батарейка Energenie EG-BA-CR2016-01      4.0        NaN
# 2                      Батарейка Energenie EG-BA-AA4-01      5.0        NaN
# 3                     Батарейка Energenie EG-BA-AAA4-01      5.0        NaN
# 4                   Батарейка Energenie EG-BA-CR2025-01      5.0        NaN
# ...                                                 ...      ...        ...
# 5868  Ноутбук Acer Nitro 5 ANV15-41 Obsidian Black (...  22999.0        NaN
# 5888  Ноутбук Acer Nitro 5 ANV15-41 Obsidian Black (...  24999.0        NaN
# 5891  Ноутбук ASUS TUF Gaming FA507NU Gray (FA507NU-...  25999.0        NaN
# 5893  Ноутбук Acer Nitro 5 ANV15-51 Obsidian Black (...  26999.0        NaN
# 5895  Ноутбук Acer Nitro 5 AN515-58 Obsidian Black (...  29999.0        NaN
#
#       action_sale  sale                  category  \
# 0               0   NaN  televizory-i-elektronika
# 1               0   NaN  televizory-i-elektronika
# 2               0   NaN  televizory-i-elektronika
# 3               0   NaN  televizory-i-elektronika
# 4               0   NaN  televizory-i-elektronika
# ...           ...   ...                       ...
# 5868            0   NaN     kompyuternaya-tehnika
# 5888            0   NaN     kompyuternaya-tehnika
# 5891            0   NaN     kompyuternaya-tehnika
# 5893            0   NaN     kompyuternaya-tehnika
# 5895            0   NaN     kompyuternaya-tehnika
#
#                            subcategory                             group  \
# 0     batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 1     batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 2     batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 3     batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# 4     batareyki-i-zaryadnye-ustroystva  batareyki-i-zaryadnye-ustroystva
# ...                                ...                               ...
# 5868             noutbuki-planshety...                          noutbuki
# 5888             noutbuki-planshety...                          noutbuki
# 5891             noutbuki-planshety...                          noutbuki
# 5893             noutbuki-planshety...                          noutbuki
# 5895             noutbuki-planshety...                          noutbuki
#
#       count_group  count_group_presence   dif_price
# 0              78                    77  199.750000
# 1              78                    77  199.750000
# 2              78                    77  199.750000
# 3              78                    77  199.750000
# 4              78                    77  199.750000
# ...           ...                   ...         ...
# 5868           83                    69    5.653185
# 5888           83                    69    5.653185
# 5891           83                    69    5.653185
# 5893           83                    69    5.653185
# 5895           83                    69    5.653185
#
# [4695 rows x 15 columns]
