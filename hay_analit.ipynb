# %% [markdown]
# # аналитика хайтек

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs
import re
from tqdm.notebook import trange, tqdm
from tqdm.gui import tqdm as tqdm_gui
from IPython.display import display

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# импортируем библиотеки

# %%
t = pd.read_csv('csv/hi_tech_end_2024_6_10.csv')

# %% [markdown]
# загружаем файл

# %%
t.subcategory.unique()
# Out:
# array(['batareyki_i_zaryadnye_ustroystva', 'nastennye_krepleniya_dlya_tv',
#        'audiotehnika', 'smartfony_i_aksessuary', 'multimedia',
#        'pristavki_dlya_tv', 'gadzhety', 'telefony_dect_i_provodnye',
#        'tovary_apple', 'sport_i_otdyh',
#        'hd_cvi_videokamera_dahua_dh_hac_hdw1220mp_0280b_s2',
#        'umnyy_dom_s_yandeks', 'televizory', 'pylesosy_i_aksessuary',
#        'tehnika_karcher', 'aksessuary_dlya_melkoy_bytovoy_tehniki',
#        'tovary_dlya_uhoda_za_odezhdoy', 'minimoyki',
#        'prigotovlenie_napitkov', 'melkaya_tehnika_dlya_kuhni',
#        'tehnika_dlya_krasoty', 'stiralnye_i_sushilnye_mashiny',
#        'krupnaya_tehnika_dlya_kuhni', 'tehnika_dlya_zdorovya',
#        'klimaticheskaya_tehnika', 'ustanovka_bytovoy_tehniki',
#        'prigotovlenie_pischi', 'teploventilyator_tesy_hl_213v',
#        'elektroplita_zilan_zln8092', 'tekhnika_dlya_doma',
#        'kolpachok_rj_45_gembird_bt5bk_5', 'nakopiteli',
#        'konnektor_rj_45_gembird_cat5e_lc_8p8c_001',
#        'setevoe_oborudovanie', 'aksessuary', 'rashodnye_materialy',
#        'periferiynye_ustroystva', 'orgtehnika', 'komplektuyuschie',
#        'krepleniya_dlya_monitora', 'elektropitanie',
#        'konnektor_rj_45_gembird_cat5e_lc_8p8c_001_100',
#        'rul_sven_gc_w300', 'xbox_playstation', 'rul_sven_gc_w800_usb',
#        'monitory', 'proektory_i_ekrany', 'noutbuki_planshety...',
#        'processor_intel_core_i5_12400_box',
#        'processor_amd_ryzen_r7_5800x_box',
#        'kreslo_komp._obrotowy_q_025_cvet_chernyy_sl_ucenka',
#        'kreslo_komp._obrotowy_q_g2_cvet_rozovyy_sl',
#        'kreslo_komp._obrotowy_q_g2_cvet_sine_chernyy_sl',
#        'kompyuternaya_mebel',
#        'kreslo_komp._obrotowy_q_g2_cvet_rozovo_seryy_sl',
#        'kreslo_komp._tokio_cvet_seryy_barhat_18_ami',
#        'kreslo_komp._siti_cvet_bezhevyy_holland_velvet_03_ami',
#        'kreslo_furniture_ch_801_black_orange',
#        'kreslo_furniture_ch_804_grey_blue',
#        'kreslo_furniture_ch_805_black', 'kreslo_furniture_d038_black',
#        'kreslo_furniture_d038_gray',
#        'kreslo_komp._obrotowy_q_078_cvet_chernyy_sl',
#        'gotovimsya_k_shkole_so_skidkami_do_30',
#        'kreslo_komp._obrotowy_q_025_cvet_sero_chernyy_sl',
#        'kreslo_komp._dexter_cvet_rozovo_belyy_sl',
#        'kreslo_komp._obrotowy_q_025_cvet_seryy_material_sl',
#        'kreslo_komp._daisy_cvet_seryy_sl',
#        'kreslo_komp._daisy_cvet_rozovyy_sl',
#        'kreslo_komp._dolly_cvet_rozovyy_sl',
#        'kreslo_komp._camaro_cvet_cherno_zheltyy_sl',
#        'kreslo_komp._camaro_cvet_cherno_krasnyy_sl',
#        'kreslo_komp._camaro_cvet_cherno_seryy_sl',
#        'kreslo_komp._obrotowy_q_319_cvet_chernyy_sl',
#        'kreslo_komp._obrotowy_q_319_cvet_seryy_sl',
#        'kreslo_komp._obrotowy_q_019_cvet_chernyy_sl',
#        'kreslo_furniture_3078_1_black_r',
#        'kreslo_furniture_3078_1_black_r_ucenka',
#        'kreslo_komp._obrotowy_q_033_cvet_chernyy_sl',
#        'kreslo_komp._obrotowy_q_831_cvet_seryy_sl',
#        'kreslo_furniture_3100a_black_yellow',
#        'kreslo_komp._obrotowy_q_022_cvet_belyy_sl',
#        'kreslo_komp._obrotowy_q_022_cvet_seryy_sl',
#        'kreslo_komp._obrotowy_q_022_cvet_chernyy_sl',
#        'kreslo_komp._obrotowy_q_022_cvet_rozovyy_sl',
#        'kreslo_komp._obrotowy_q_022_cvet_seryy_bluvel_14_sl',
#        'kreslo_komp._obrotowy_q_022_cvet_chernyy_bluvel_19_sl',
#        'kreslo_komp._obrotowy_q_022_cvet_seryy_material_sl',
#        'kreslo_komp._obrotowy_q_035_cvet_seryy_s_belymi_bokami_sl',
#        'kreslo_komp._q_939_cvet_cherno_seroe_sl',
#        'kreslo_komp._obrotowy_q_409_cvet_cherno_belyy_sl',
#        'kreslo_furniture_9366_beige_k_ucenka',
#        'kreslo_komp._obrotowy_q_031_cvet_bezhevyy_sl',
#        'kreslo_komp._obrotowy_q_031_cvet_seryy_sl',
#        'kreslo_komp._obrotowy_q_031_cvet_chernyy_sl',
#        'kreslo_furniture_hf_459_black',
#        'kreslo_komp._obrotowy_q_087_cvet_seryy_sl',
#        'kreslo_komp._obrotowy_q_087_cvet_chernyy_sl',
#        'kreslo_komp._obrotowy_q_229_cvet_cherno_seryy_sl',
#        'kreslo_komp._q_270_cvet_chernyy_sl',
#        'kreslo_komp._obrotowy_q_154_cvet_cheryy_sl',
#        'kreslo_furniture_9375_black_k', 'kreslo_furniture_1709_a',
#        'kreslo_furniture_1709_k', 'kreslo_furniture_1709_s',
#        'kreslo_furniture_9368_black_k', 'kreslo_furniture_9368_brown',
#        'kreslo_furniture_9368_coffee_k',
#        'kreslo_komp._obrotowy_viper_cvet_cherno_zheltyy_sl',
#        'kreslo_komp._obrotowy_viper_cvet_cherno_krasnyy_sl',
#        'kreslo_komp._obrotowy_viper_cvet_cherno_seryy_sl',
#        'kreslo_komp._viper_cvet_cherno_goluboy_sl',
#        'kreslo_furniture_a909_black',
#        'kreslo_komp._maryland_cvet_chernyy_sl',
#        'kreslo_kozhanoe_furniture_9341_black_k',
#        'kreslo_kozhanoe_furniture_9576_1_white_k',
#        'kreslo_kozhanoe_furniture_9368_black_k', 'elektroinstrument',
#        'servirovka_stola', 'kuhonnye_prinadlezhnosti', 'osveschenie',
#        'posuda_dlya_duhovok_i_mikrovolnovyh_pechey', 'bytovaya_himiya'],
#       dtype=object)

# %%
df=t[t['id']=='T-900000003']

# %% [markdown]
# t = pd.read_csv('csv/hi_tech_test1_2024_6_11.csv')

# %% [markdown]
# df = t.loc[[1529,1530,1531,1532],:]

# %%
df.head()
# Out:
#                                                                                                                                   soup_name  \
# 3164  https://hi-tech.md/bytovaya-tehnika/klimaticheskaya-tehnika/otopitelnye-pechi/pech-otopitelno-varochnaya-ogon-batareya-7-antracit-eu/
#
#                id        date availability  \
# 3164  T-900000003  2024-06-10    Предзаказ
#
#                                                       title   price  \
# 3164  Печь отопительно-варочная Огонь-батарея 7 антрацит EU  5659.0
#
#       old_price  action_sale  sale          category              subcategory  \
# 3164        NaN            0   NaN  bytovaya_tehnika  klimaticheskaya_tehnika
#
#                   group  count_group  count_group_presence  dif_price   brend  \
# 3164  otopitelnye_pechi           11                     0        NaN  другой
#
#      group_prise  тир_юности_14а  ц_тир_25_октября_69  тирасполь  \
# 3164      бюджет               0                    0          0
#
#       бенд_спортивная_5  бенд_советская_5  бенд_советская_8  бендеры  \
# 3164                  0                 0                 0        0
#
#       слободзея  днестровск  первомайск  григ_кмаркса_181а  григ_кмаркса_172  \
# 3164          0           0           0                  0                 0
#
#       григориополь  дубоссары  рыбн_вальченко_43  рыбн_кирова_135  рыбница  \
# 3164             0          0                  0                0        0
#
#       каменка  error
# 3164        0      1

# %% [markdown]
# def count_sity(x):
#     reqx = requests.get(x)
#     soup = bs(reqx.text, 'html.parser')
#     element = soup.findAll('div', class_='ty-warehouses-store__availability')
#     elem_2 = soup.findAll('div', class_='ty-breadcrumbs clearfix')
#     name = soup.findAll('span', class_='ty-breadcrumbs__current')
#     data = []
#     if len(element) == 14:
#         data.append(element[0].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[1].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[2].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[3].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[4].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[5].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[6].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[7].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[8].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[9].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[10].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[11].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[12].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(element[13].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
#         .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
#         data.append(0)
#         if name[0].text.find('/')<0:
#             ss = elem_2[0].text
#         else:
#             ss = elem_2[0].text[:elem_2[0].text.rfind('/')] + ' ' + elem_2[0].text[elem_2[0].text.rfind('/')+1:]
#
#         if name[0].text.find('/') == 3:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[2])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 4:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[2])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 5:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[3])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 6:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[-3])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 7:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[-4])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 8:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[-5])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 9:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[-6])
#             data.append(len(ss.split('/')))
#         return data
#     else:
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(0)
#         data.append(1)
#         if len(ss.split('/')) == 3:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[2])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 4:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[2])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 5:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[3])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 6:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[-3])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 7:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[-4])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 8:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[-5])
#             data.append(len(ss.split('/')))
#         elif len(ss.split('/')) == 9:
#             data.append(ss.split("/")[1])
#             data.append(ss.split("/")[2])
#             data.append(ss.split("/")[-6])
#             data.append(len(ss.split('/')))
#         return data

# %%
def count_sity(x):
    try:
        reqx = requests.get(x)
        soup = bs(reqx.text, 'html.parser')    
        element = soup.findAll('div', class_='ty-warehouses-store__availability')
        elem_2 = soup.findAll('div', class_='ty-breadcrumbs clearfix')
        name = soup.findAll('span', class_='ty-breadcrumbs__current')
        data = []
        try:
            data.append(element[0].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[1].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[2].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[3].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[4].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[5].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[6].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[7].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[8].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[9].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[10].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[11].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[12].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:
            data.append(element[13].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            data.append(np.NaN)
        try:        
            if name[0].text.find('/')<0:
                ss = elem_2[0].text
            else:
                ss = elem_2[0].text[:elem_2[0].text.rfind('/')] + ' ' + elem_2[0].text[elem_2[0].text.rfind('/')+1:]           

            if len(ss.split('/')) == 3:
                data.append(ss.split("/")[1])
                data.append(ss.split("/")[2])
                data.append(ss.split("/")[2])
                data.append(len(ss.split('/')))
            elif len(ss.split('/')) == 4:
                data.append(ss.split("/")[1])
                data.append(ss.split("/")[2])
                data.append(ss.split("/")[2])  
                data.append(len(ss.split('/')))
            elif len(ss.split('/')) == 5:
                data.append(ss.split("/")[1])
                data.append(ss.split("/")[2])
                data.append(ss.split("/")[3]) 
                data.append(len(ss.split('/')))
            elif len(ss.split('/')) == 6:
                data.append(ss.split("/")[1])
                data.append(ss.split("/")[2])
                data.append(ss.split("/")[-3])  
                data.append(len(ss.split('/')))
            elif len(ss.split('/')) == 7:
                data.append(ss.split("/")[1])
                data.append(ss.split("/")[2])
                data.append(ss.split("/")[-4])  
                data.append(len(ss.split('/')))
            elif len(ss.split('/')) == 8:
                data.append(ss.split("/")[1])
                data.append(ss.split("/")[2])
                data.append(ss.split("/")[-5])  
                data.append(len(ss.split('/')))
            elif len(ss.split('/')) == 9:
                data.append(ss.split("/")[1])
                data.append(ss.split("/")[2])
                data.append(ss.split("/")[-6]) 
                data.append(len(ss.split('/')))
            return data
        except:
            data.append(np.NaN)
            data.append(np.NaN)
            data.append(np.NaN)
            data.append(np.NaN)
            return data
    except:
        pass

# %%
tqdm.pandas()
df['count_sity']= df['soup_name'].progress_apply(count_sity)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df['Тир_Юности_14А'] = df['count_sity'].str[0]
df['Ц_Тир_25_Октября_69'] = df['count_sity'].str[1]
df['Бенд_Спортивная_5'] = df['count_sity'].str[2]
df['Бенд_Советская_5'] = df['count_sity'].str[3]
df['Бенд_Советская_8'] = df['count_sity'].str[4]
df['СЛОБОДЗЕЯ'] = df['count_sity'].str[5]
df['ДНЕСТРОВСК'] = df['count_sity'].str[6]
df['Первомайск'] = df['count_sity'].str[7]
df['Григ_КМаркса_181А'] = df['count_sity'].str[8]
df['Григ_КМаркса_172'] = df['count_sity'].str[9]
df['ДУБОССАРЫ'] = df['count_sity'].str[10]
df['Рыбн_Вальченко_43'] = df['count_sity'].str[11]
df['Рыбн_Кирова_135'] = df['count_sity'].str[12]
df['Каменка'] = df['count_sity'].str[13]
df['_category'] = df['count_sity'].str[14]
df['_subcategory'] = df['count_sity'].str[15]
df['_group'] = df['count_sity'].str[16]
df['len'] = df['count_sity'].str[17]

# %%
df
# Out:
#                                                                                                                                   soup_name  \
# 3164  https://hi-tech.md/bytovaya-tehnika/klimaticheskaya-tehnika/otopitelnye-pechi/pech-otopitelno-varochnaya-ogon-batareya-7-antracit-eu/
#
#                id        date availability  \
# 3164  T-900000003  2024-06-10    Предзаказ
#
#                                                       title   price  \
# 3164  Печь отопительно-варочная Огонь-батарея 7 антрацит EU  5659.0
#
#       old_price  action_sale  sale          category              subcategory  \
# 3164        NaN            0   NaN  bytovaya_tehnika  klimaticheskaya_tehnika
#
#                   group  count_group  count_group_presence  dif_price   brend  \
# 3164  otopitelnye_pechi           11                     0        NaN  другой
#
#      group_prise  тир_юности_14а  ц_тир_25_октября_69  тирасполь  \
# 3164      бюджет               0                    0          0
#
#       бенд_спортивная_5  бенд_советская_5  бенд_советская_8  бендеры  \
# 3164                  0                 0                 0        0
#
#       слободзея  днестровск  первомайск  григ_кмаркса_181а  григ_кмаркса_172  \
# 3164          0           0           0                  0                 0
#
#       григориополь  дубоссары  рыбн_вальченко_43  рыбн_кирова_135  рыбница  \
# 3164             0          0                  0                0        0
#
#       каменка  error  \
# 3164        0      1
#
#                                                                                                                                          count_sity  \
# 3164  [0, 0, 0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, Бытовая техника, Климатическая техника, Отопительные печи, 5]
#
#      Тир_Юности_14А Ц_Тир_25_Октября_69 Бенд_Спортивная_5  Бенд_Советская_5  \
# 3164              0                   0                 0               NaN
#
#       Бенд_Советская_8  СЛОБОДЗЕЯ  ДНЕСТРОВСК  Первомайск  Григ_КМаркса_181А  \
# 3164               NaN        NaN         NaN         NaN                NaN
#
#       Григ_КМаркса_172  ДУБОССАРЫ  Рыбн_Вальченко_43  Рыбн_Кирова_135  \
# 3164               NaN        NaN                NaN              NaN
#
#       Каменка  _category  _subcategory  _group              len
# 3164      NaN        NaN           NaN     NaN  Бытовая техника
