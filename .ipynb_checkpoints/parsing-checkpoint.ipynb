# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import re
from tqdm import trange, tqdm

# %%
reqx = requests.get('https://hi-tech.md/instrumenty-i-oborudovanie/page-33')

# %%
soup = bs(reqx.text, 'html.parser')

# %%
data = pd.DataFrame({'soup_name':pd.Series(soup.findAll('div', class_='ypi-grid-list__item_body'))})
data.head()
# Out:
#                                            soup_name
# 0  [[ , [\n, <input name="appearance[show_sku]" t...
# 1  [[ , [\n, <input name="appearance[show_sku]" t...
# 2  [[ , [\n, <input name="appearance[show_sku]" t...
# 3  [[ , [\n, <input name="appearance[show_sku]" t...
# 4  [[ , [\n, <input name="appearance[show_sku]" t...

# %%
len(data)
# Out:
# 16

# %%
def names_correct(x):
    name = str(x)
    #str_name = (re.split("class", name))
    return  name

# %%
data['soup_name'] = data['soup_name'].apply(names_correct)

# %%
data.head()
# Out:
#                                            soup_name
# 0  <div class="ypi-grid-list__item_body" style="m...
# 1  <div class="ypi-grid-list__item_body" style="m...
# 2  <div class="ypi-grid-list__item_body" style="m...
# 3  <div class="ypi-grid-list__item_body" style="m...
# 4  <div class="ypi-grid-list__item_body" style="m...

# %%
def find_id(x):
    find = x.find('span class="ty-control-group__item"')
    start = find+len('span class="ty-control-group__item"')+1
    stop = find+12+ len('span class="ty-control-group__item"')
    xxx = x[start: stop]
    return xxx

# %%
data['id'] = data['soup_name'].apply(find_id)

# %%
def find_availability(t):
    find = t.find('i class="material-icons"')
    find = t.find('</i>', find)
    start = find+len('</i>')
    stop = t.find('\n', find)
    xxx = t[start: stop]
    return xxx

# %%
data['availability'] = data['soup_name'].apply(find_availability)

# %%
def find_title(t):
    find = t.find('a class="product-title"')
    find = t.find('title=', find)
    start = find+len('title=')+1
    stop = t.find('>', find)-1
    xxx = t[start: stop]
    return xxx

# %%
data['title'] = data['soup_name'].apply(find_title)

# %%
def find_price(t):
    find = t.find('span class="ty-price-num"')
    find = t.find('>', find)
    start = find+len('>')
    stop = t.find('<', find)
    xxx = t[start: stop]
    xxx = xxx.replace(u'\xa0',u'')
    return xxx

# %%
data['price'] = data['soup_name'].apply(find_price)

# %%
def find_old_price(t):
    find = t.find('span class="ty-strike"')
    find = t.find('span class="ty-list-price ty-nowrap"',find)
    find = t.find('>', find)
    start = find+len('>')
    stop = t.find('<', find)
    xxx = t[start: stop]
    xxx = xxx.replace(u'\xa0',u'')
    return xxx

# %%
data['old_price'] = data['soup_name'].apply(find_old_price)

# %%
data
# Out:
#                                             soup_name           id  \
# 0   <div class="ypi-grid-list__item_body" style="m...  Т-000019420
# 1   <div class="ypi-grid-list__item_body" style="m...  Т-000051540
# 2   <div class="ypi-grid-list__item_body" style="m...  Т-000083200
# 3   <div class="ypi-grid-list__item_body" style="m...  Т-000056675
# 4   <div class="ypi-grid-list__item_body" style="m...  Т-000038497
# 5   <div class="ypi-grid-list__item_body" style="m...  Т-000048304
# 6   <div class="ypi-grid-list__item_body" style="m...  Т-000019159
# 7   <div class="ypi-grid-list__item_body" style="m...  Т-000032670
# 8   <div class="ypi-grid-list__item_body" style="m...  Т-000006726
# 9   <div class="ypi-grid-list__item_body" style="m...  Т-000048597
# 10  <div class="ypi-grid-list__item_body" style="m...  Т-000079404
# 11  <div class="ypi-grid-list__item_body" style="m...  Т-000022317
# 12  <div class="ypi-grid-list__item_body" style="m...  Т-000074805
# ...

# %%
t = data.loc[0,'soup_name']
t = str(t)
find = t.find('span class="ty-strike"')
find = t.find('span class="ty-list-price ty-nowrap"',find)
find = t.find('>', find)
start = find+len('>')
stop = t.find('<', find)
xxx = t[start: stop]
xxx = xxx.replace(u'\xa0',u'')
xxx
# Out:
# '34'

# %%
t = pd.DataFrame({'soup_name':pd.Series(soup.findAll('div', class_='ypi-grid-list__item_body'))}).loc[0,'soup_name']
t
# Out:
# <div class="ypi-grid-list__item_body" style="min-height: 430px"><div class="stock-block"> <div class="ty-control-group ty-sku-item cm-hidden-wrapper cm-reload-16062" id="sku_update_16062">
# <input name="appearance[show_sku]" type="hidden" value="1">
# <label class="ty-control-group__label" id="sku_16062">КОД:</label>
# <span class="ty-control-group__item">Т-000019420</span>
# </input></div>
# <div class="cm-reload-16062 stock-wrap" id="product_amount_update_16062">
# <input name="appearance[show_product_amount]" type="hidden" value="1">
# <a class="ty-control-group product-list-field cm-external-click" data-ca-external-click-id="availability_in_stores" href="#availability_in_stores">
# <span class="ty-qty-in-stock ty-control-group__item" id="in_stock_info_16062">
# <i class="material-icons"></i>В наличии
# </span>
# </a>
# </input></div>
# </div><div class="ty-grid-list__image" style="height: 230px;">
# <div class="ypi-list-bt-block hidden">
# ...

# %%
def parsing(url, num):
    data = pd.DataFrame(columns=['soup_name', 'id', 'availability', 'title', 'price', 'old_price'])
    for i in tqdm(range(num)):        
        reqx = requests.get(url + str(i + 1))
        soup = bs(reqx.text, 'html.parser')
        datax = pd.DataFrame({'soup_name':pd.Series(soup.findAll('div', class_='ypi-grid-list__item_body'))})
        datax['soup_name'] = datax['soup_name'].apply(names_correct)
        datax['id'] = datax['soup_name'].apply(find_id)
        datax['availability'] = datax['soup_name'].apply(find_availability)
        datax['title'] = datax['soup_name'].apply(find_title)
        datax['price'] = datax['soup_name'].apply(find_price)
        datax['old_price'] = datax['soup_name'].apply(find_old_price)
        data = pd.concat([data, datax], ignore_index=True)
    return data

# %%
df = parsing('https://hi-tech.md/kompyuternaya-tehnika/page-', 75)
df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 75/75 [01:17<00:00,  1.04s/it]
#                                               soup_name           id  \
# 0     <div class="ypi-grid-list__item_body" style="m...  Т-000042701
# 1     <div class="ypi-grid-list__item_body" style="m...  Т-000064071
# 2     <div class="ypi-grid-list__item_body" style="m...  Т-000061104
# 3     <div class="ypi-grid-list__item_body" style="m...  Т-000090552
# 4     <div class="ypi-grid-list__item_body" style="m...  Т-000057466
# ...                                                 ...          ...
# 2668  <div class="ypi-grid-list__item_body" style="m...  Т-000089357
# 2669  <div class="ypi-grid-list__item_body" style="m...  Т-000089359
# 2670  <div class="ypi-grid-list__item_body" style="m...  Т-000089360
# 2671  <div class="ypi-grid-list__item_body" style="m...  Т-000089355
# 2672  <div class="ypi-grid-list__item_body" style="m...  Т-000089356
#
# ...

# %%
df.groupby('availability')['availability'].count()
# Out:
# availability
# В наличии    2307
# Предзаказ     366
# Name: availability, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2673 entries, 0 to 2672
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   soup_name     2673 non-null   object
#  1   id            2673 non-null   object
#  2   availability  2673 non-null   object
#  3   title         2673 non-null   object
#  4   price         2673 non-null   object
#  5   old_price     2673 non-null   object
# dtypes: object(6)
# memory usage: 125.4+ KB

# %%
df.to_csv('csv/hi_kompteh_010524.csv', index=False)

# %%
dgh = pd.read_csv('csv/hi_kompteh_010524.csv')

# %%
dgh
dgh['cut'] = pd.cut(dgh['price'],5)
dgh['qcut'] = pd.qcut(dgh['price'],5)

# %%
dgh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2673 entries, 0 to 2672
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   soup_name     2673 non-null   object
#  1   id            2673 non-null   object
#  2   availability  2673 non-null   object
#  3   title         2673 non-null   object
#  4   price         2673 non-null   int64
#  5   old_price     565 non-null    float64
#  6   cut           2673 non-null   category
#  7   qcut          2673 non-null   category
# dtypes: category(2), float64(1), int64(1), object(4)
# memory usage: 131.1+ KB

# %%
dgh
# Out:
#                                               soup_name           id  \
# 0     <div class="ypi-grid-list__item_body" style="m...  Т-000042701
# 1     <div class="ypi-grid-list__item_body" style="m...  Т-000064071
# 2     <div class="ypi-grid-list__item_body" style="m...  Т-000061104
# 3     <div class="ypi-grid-list__item_body" style="m...  Т-000090552
# 4     <div class="ypi-grid-list__item_body" style="m...  Т-000057466
# ...                                                 ...          ...
# 2668  <div class="ypi-grid-list__item_body" style="m...  Т-000089357
# 2669  <div class="ypi-grid-list__item_body" style="m...  Т-000089359
# 2670  <div class="ypi-grid-list__item_body" style="m...  Т-000089360
# 2671  <div class="ypi-grid-list__item_body" style="m...  Т-000089355
# 2672  <div class="ypi-grid-list__item_body" style="m...  Т-000089356
#
#      availability                                              title  price  \
# ...
