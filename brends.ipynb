# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs
import re
from tqdm import trange, tqdm

# %%
brend = pd.read_excel('csv/brend.xlsx')

# %%
brend = brend.name.unique()
# Out:
# array(['Fairywill', 'Snakebyke', 'Denver', 'Wekome', 'Leran', 'Valve',
#        'Security Force', 'Epik', 'Epic', 'Honor', 'Boya', 'Seasonic',
#        'ABB', 'Ajax', 'Borofone', 'ZTE', 'Ecovacs', 'HyperX', 'Google',
#        'Nothing', 'Frost Mining', 'Laird', 'Mill', 'Rode', 'ElicoCamp',
#        'Arton', 'Optoma', 'Akai', 'Chuwi', 'Onikuma', 'K&M group',
#        'Alcatel', 'Cat eye', 'Falcon Eye', 'КВТ', 'Uniel',
#        'Schneider Electric', 'EL-BI', 'Союз', 'Amazon', 'IEK',
#        'Electrika', 'Bissel', 'Bestway', 'Salter', 'Hutt', 'Ebmpapst',
#        'Nutribullet', 'Beper', 'Resto', 'Marshall', 'Osram', 'Мегаватт',
#        'Космос', 'Pensofal', 'Jata', 'Grwibeou', 'Edge', 'Kingsdun',
#        'Toocki', 'Bavin', 'Fifine', 'Noyafa', 'Blaze', 'TEQQO', 'WZATCO',
#        'Technaxx', 'OnePlus', 'Poco', 'Nillkin', 'Domo', 'Concept',
#        'Camshield', 'Pathfinder', 'Miele', 'Shona Medical', 'Royal clima',
# ...
