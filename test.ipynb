# %%
import pandas as pd
import numpy as np
import datetime as dt
import requests
from bs4 import BeautifulSoup as bs
import re
from tqdm.notebook import trange, tqdm
from tqdm.gui import tqdm as tqdm_gui
from IPython.display import display

# %%
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %%
today = pd.to_datetime('today').normalize()
today = today.to_pydatetime()
df = pd.read_csv('csv/hi_tech_test_'+dt.datetime.now().strftime('%Y_%m_%d')+'.csv')

# %%
df.columns
# Out:
# Index(['url', 'id', 'date', 'availability', 'title', 'price', 'old_price'], dtype='object')

# %% [markdown]
# df.drop(['тир_юности_14а', 'тир_25_октября_69', 'бенд_спортивная_5',
#        'бенд_советская_5', 'бенд_советская_8', 'слободзея', 'днестровск',
#        'первомайск', 'григ_кмаркса_181а', 'григ_кмаркса_172', 'дубоссары',
#        'рыбн_вальченко_43', 'рыбн_кирова_135', 'каменка', '_category',
#        '_subcategory', '_group', 'len'], axis= 1 , inplace= True )

# %%
def xxx(x):
    try:
        reqx = requests.get(x)
        soup = bs(reqx.text, 'html.parser')    
        element = soup.findAll('div', class_='ty-warehouses-store__availability')
        elem_2 = soup.findAll('div', class_='ty-breadcrumbs clearfix')
        name = soup.findAll('span', class_='ty-breadcrumbs__current')
        try:
            d_0 = (element[0].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_0 = (np.NaN)
        try:
            d_1 = (element[1].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_1 = (np.NaN)
        try:
            d_2 = (element[2].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_2 = (np.NaN)
        try:
            d_3 = (element[3].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_3 = (np.NaN)
        try:
            d_4 = (element[4].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_4 = (np.NaN)
        try:
            d_5 = (element[5].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_5 = (np.NaN)
        try:
            d_6 = (element[6].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_6 = (np.NaN)
        try:
            d_7 = (element[7].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_7 = (np.NaN)
        try:
            d_8 = (element[8].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_8 = (np.NaN)
        try:
            d_9 = (element[9].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_9 = (np.NaN)
        try:
            d_10 = (element[10].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_10 = (np.NaN)
        try:
            d_11 = (element[11].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_11 = (np.NaN)
        try:
            d_12 = (element[12].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_12 = (np.NaN)
        try:
            d_13 = (element[13].text.strip().replace('В наличии', '1').replace('Нет в наличии','0')
            .replace('Под заказ (1-3 дня)','0').replace('nan','0'))
        except:
            d_13 = (np.NaN)
        try:            
            ss = elem_2[0].text.replace('/'+str(name[0].text),'').replace('\n','')
        except:
            ss = '0/0/0/0'
        if str(type(ss)) == "<class 'NoneType'>":
            ss = '0/0/0/0'
        else:
            pass
        
        try:            
            if len(ss.split('/')) <= 3:
                d_14 = (ss.split("/")[1])
                d_15 = (ss.split("/")[2])
                d_16 = (ss.split("/")[2])
                d_17 = (len(ss.split('/')))
            elif len(ss.split('/')) > 3:
                d_14 = (ss.split("/")[1])
                d_15 = (ss.split("/")[2])
                d_16 = (ss.split("/")[3])  
                d_17 = (len(ss.split('/')))
                
            return pd.Series([(d_0), (d_1), (d_2), (d_3), (d_4), (d_5), (d_6), (d_7), (d_8), (d_9), (d_10), (d_11), (d_12), (d_13), (d_14), (d_15), (d_16), (d_17)])
        except:
            d_14 = (np.NaN)
            d_15 = (np.NaN)
            d_16 = (np.NaN)
            d_17 = (np.NaN)
            return pd.Series([(d_0), (d_1), (d_2), (d_3), (d_4), (d_5), (d_6), (d_7), (d_8), (d_9), (d_10), (d_11), (d_12), (d_13), (d_14), (d_15), (d_16), (d_17)])
    except:
        pass

# %%
t = df.sample(20)

# %%
tqdm.pandas() 
t[['тир_юности_14а','тир_25_октября_69','бенд_спортивная_5','бенд_советская_5','бенд_советская_8','слободзея','днестровск',
   'первомайск','григ_кмаркса_181а','григ_кмаркса_172','дубоссары','рыбн_вальченко_43','рыбн_кирова_135','каменка',
   '_category','_subcategory','_group','len']] = t['url'].progress_apply(xxx)
t
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#                                                                                                                                                               url  \
# 2033                                                             https://hi-tech.md/bytovaya-tehnika/prigotovlenie-pischi/multivarki/multivarka-brock-mc-1005-5l/
# 3020                                                                https://hi-tech.md/bytovaya-tehnika/prigotovlenie-pischi/elektrogrili/el.gril-tefal-gc722d34/
# 7                               https://hi-tech.md/televizory-i-elektronika/batareyki-i-zaryadnye-ustroystva/adapter-perehodnik-dlya-akkum.-panasonic-bq-bs2e-2e/
# 5409                                        https://hi-tech.md/kompyuternaya-tehnika/periferiynye-ustroystva/veb-kamery/veb-kamera-logitech-streamcam-960-001297/
# 6180  https://hi-tech.md/instrumenty-i-oborudovanie/elektroinstrument/nabory-instrumentov-i-izmeritelnye-pribory/nivelir-laser-st-fm-4v1h-multi-line-stht77514-1/
# 6466                                          https://hi-tech.md/tovary-dlya-doma/servirovka-stola/salatniki-i-blyuda/luminarc-diwali-black-salatnik-12-sm.-4531/
# 3083                                                    https://hi-tech.md/bytovaya-tehnika/klimaticheskaya-tehnika/kondicionery/kondicioner-tcl-tac-12chsa-xab1/
# 1447                                                                https://hi-tech.md/bytovaya-tehnika/minimoyki/pistolet-karcher-2.641-959.0-univ.d-kr.shlanga/
# 208                                                     https://hi-tech.md/kompyuternaya-tehnika/multimedia/naushniki/vkladyshi/naushniki-panasonic-rp-tcm115gck/
# 7021                                      https://hi-tech.md/tovary-dlya-doma/prigotovlenie-napitkov/zavarochnye-chayniki/zavarnik-fissman-flat-white-9114-0-35l/
# 1395                                              https://hi-tech.md/bytovaya-tehnika/melkaya-tehnika-dlya-kuhni/vesy-kuhonnye/vesy-kuhon-polaris-pks-0323dl-3kg/
# 4695                                                            https://hi-tech.md/kompyuternaya-tehnika/periferiynye-ustroystva/myshi/usb/mysh-usb-sven-rx-g990/
# 5127                                           https://hi-tech.md/kompyuternaya-tehnika/sport-i-otdyh/hd-cvi-kamery/ip-kamery/ip-videokamera-tp-link-tapo-c320ws/
# 4452                            https://hi-tech.md/kompyuternaya-tehnika/periferiynye-ustroystva/myshi/wireless/mysh-wireless-logitech-m171-blue-grey-910-006866/
# 4183                                            https://hi-tech.md/kompyuternaya-tehnika/periferiynye-ustroystva/myshi/wireless/mysh-wireless-sven-rx-220w-black/
# 6013                        https://hi-tech.md/mebel-tekstil/kompyuternaya-mebel/ofisnye-kresla-i-stulya/komp.-kresla/kreslo-komp.-oregon-cvet-chernyy-sl-ucenka/
# 872                                                                  https://hi-tech.md/televizory-i-elektronika/audiotehnika/saundbary/saundbar-hisense-u5120gw/
# 565                                       https://hi-tech.md/televizory-i-elektronika/audiotehnika/akusticheskie-sistemy/portativnaya/akustika-sven-ps-650-black/
# 8471                                           https://hi-tech.md/tovary-dlya-doma/prigotovlenie-pischi/skovorody/skovoroda-fissman-diamond-14306-28sm-antiprig./
# 783                                        https://hi-tech.md/televizory-i-elektronika/audiotehnika/akusticheskie-sistemy/portativnaya/akustika-blaupunkt-ps10db/
#
#                id        date availability  \
# 2033  Т-000080987  2024-06-13    В наличии
# 3020  Т-000060151  2024-06-13    В наличии
# 7     Т-000039418  2024-06-13    В наличии
# 5409  Т-000092777  2024-06-13    В наличии
# 6180  Т-000080396  2024-06-13    В наличии
# 6466  Т-000076452  2024-06-13    В наличии
# 3083  Т-000089641  2024-06-13    В наличии
# 1447  Т-000006698  2024-06-13    В наличии
# 208   Т-000055469  2024-06-13    В наличии
# 7021  Т-000082544  2024-06-13    В наличии
# 1395  Т-000054490  2024-06-13    В наличии
# 4695  Т-000091743  2024-06-13    В наличии
# 5127  Т-000082463  2024-06-13    В наличии
# 4452  Т-000087867  2024-06-13    В наличии
# 4183  Т-000052730  2024-06-13    В наличии
# 6013  Т-000087962  2024-06-13    В наличии
# 872   Т-000087680  2024-06-13    В наличии
# 565   Т-000059410  2024-06-13    В наличии
# 8471  Т-000080326  2024-06-13    В наличии
# 783   Т-000068656  2024-06-13    В наличии
#
#                                                          title   price  \
# 2033                              мультиварка Brock MC 1005 5л   888.0
# 3020                               Электрогриль Tefal GC722D34  4449.0
# 7           Адаптер-переходник для аккум. Panasonic BQ-BS2E/2E    11.0
# 5409                Веб-камера Logitech StreamCam (960-001297)  2799.0
# 6180  Нивелир Stanley LASER ST FM 4V1H MULTI-LINE STHT77514-1   2069.0
# 6466              Luminarc DIWALI Black салатник 12 см. (4531)    34.0
# 3083                           кондиционер TCL TAC-12CHSA/XAB1  4859.0
# 1447             пистолет Karcher 2.641-959.0 унив.д/кр.шланга   278.0
# 208                            наушники Panasonic RP-TCM115GCK   149.0
# 7021                    заварник Fissman Flat White 9114 0,35л    77.0
# 1395                      Весы кухонные Polaris PKS 0323DL 3кг   231.0
# 4695                                     Мышь USB Sven RX-G990   399.0
# 5127                        IP-видеокамера TP-Link Tapo C320WS  1379.0
# 4452        Мышь Wireless Logitech M171 Blue Grey (910-006866)   199.0
# 4183                          Мышь Wireless Sven RX-220W Black    99.0
# 6013               Кресло комп. OREGON цвет черный (SL) Уценка  3149.0
# 872                                   Саундбар Hisense U5120GW  8999.0
# 565                                 Акустика Sven PS-650 Black  1549.0
# 8471            сковорода Fissman Diamond 14306 28см антиприг.   510.0
# 783             Акустика Blaupunkt PS10DB (+2 мик. беспровод.)  5799.0
#
#       old_price тир_юности_14а тир_25_октября_69 бенд_спортивная_5  \
# 2033     1040.0              1                 1                 1
# 3020        NaN              1                 1                 1
# 7          21.0              0                 0                 0
# 5409        NaN              1                 1                 1
# 6180     2299.0              0                 0                 1
# 6466        NaN              1                 1                 1
# 3083        NaN              1                 1                 1
# 1447      347.0              1                 1                 1
# 208         NaN              1                 1                 1
# 7021        NaN              0                 0                 0
# 1395      272.0              1                 1                 1
# 4695        NaN              1                 1                 1
# 5127        NaN              0                 1                 1
# 4452        NaN              1                 1                 1
# 4183        NaN              1                 1                 1
# 6013     4499.0              0                 1                 0
# 872         NaN              1                 1                 0
# 565         NaN              1                 1                 1
# 8471        NaN              1                 1                 1
# 783      6899.0              0                 1                 0
#
#      бенд_советская_5 бенд_советская_8 слободзея днестровск первомайск  \
# 2033                1                0         1          1          1
# 3020                1                0         1          1          1
# 7                   1                0         0          0          0
# 5409                1                0         0          1          0
# 6180                0                0         0          0          0
# 6466                1                0         1          1          1
# 3083                1                0         1          1          1
# 1447                1                0         1          1          0
# 208                 1                0         1          1          1
# 7021                0                0         0          0          0
# 1395                1                0         0          0          0
# 4695                1                0         1          1          1
# 5127                1                0         1          1          0
# 4452                1                0         1          1          1
# 4183                1                0         1          1          1
# 6013                0                0         0          0          0
# 872                 1                0         0          0          0
# 565                 1                0         1          1          1
# 8471                1                0         1          1          0
# 783                 0                0         0          0          0
#
#      григ_кмаркса_181а григ_кмаркса_172 дубоссары рыбн_вальченко_43  \
# 2033                 1                0         1                 1
# 3020                 1                0         1                 1
# 7                    0                0         0                 0
# 5409                 1                0         1                 0
# 6180                 0                0         0                 0
# 6466                 1                0         1                 1
# 3083                 1                0         1                 1
# 1447                 1                0         1                 1
# 208                  1                0         1                 1
# 7021                 0                0         0                 0
# 1395                 0                0         0                 0
# 4695                 1                0         1                 1
# 5127                 0                0         0                 0
# 4452                 1                0         1                 1
# 4183                 1                0         1                 1
# 6013                 0                0         0                 0
# 872                  0                0         0                 0
# 565                  1                0         1                 1
# 8471                 1                0         1                 1
# 783                  0                0         0                 0
#
#      рыбн_кирова_135 каменка                 _category  \
# 2033               1       1           Бытовая техника
# 3020               1       1           Бытовая техника
# 7                  0       0  Телевизоры и электроника
# 5409               1       0      Компьютерная техника
# 6180               1       0          Стройка и ремонт
# 6466               1       1           Товары для дома
# 3083               1       1           Бытовая техника
# 1447               1       1           Бытовая техника
# 208                1       1      Компьютерная техника
# 7021               1       0           Товары для дома
# 1395               1       0           Бытовая техника
# 4695               1       1      Компьютерная техника
# 5127               1       0      Компьютерная техника
# 4452               1       0      Компьютерная техника
# 4183               1       1      Компьютерная техника
# 6013               0       0          Мебель, текстиль
# 872                1       0  Телевизоры и электроника
# 565                1       1  Телевизоры и электроника
# 8471               1       1           Товары для дома
# 783                1       0  Телевизоры и электроника
#
#                          _subcategory  \
# 2033               Приготовление пищи
# 3020               Приготовление пищи
# 7     Батарейки и зарядные устройства
# 5409          Периферийные устройства
# 6180               Электроинструменты
# 6466                 Сервировка стола
# 3083            Климатическая техника
# 1447                        Минимойки
# 208                       Мультимедиа
# 7021           Приготовление напитков
# 1395         Мелкая техника для кухни
# 4695          Периферийные устройства
# 5127                     Видеотехника
# 4452          Периферийные устройства
# 4183          Периферийные устройства
# 6013                 Мебель для офиса
# 872                      Аудиосистемы
# 565                      Аудиосистемы
# 8471               Приготовление пищи
# 783                      Аудиосистемы
#
#                                            _group  len
# 2033                                  Мультиварки    4
# 3020                                 Электрогрили    4
# 7                 Батарейки и зарядные устройства    3
# 5409                                   Веб камеры    4
# 6180  Наборы инструментов и измерительные приборы    4
# 6466                           Салатники и блюда     4
# 3083                                 Кондиционеры    4
# 1447                                    Минимойки    3
# 208                                      Наушники    5
# 7021                           Заварочные чайники    4
# 1395                                Весы кухонные    4
# 4695                                         Мыши    5
# 5127                              Видеонаблюдение    5
# 4452                                         Мыши    5
# 4183                                         Мыши    5
# 6013                      Офисные кресла и стулья    5
# 872                                     Саундбары    4
# 565                          Акустические системы    5
# 8471                                    Сковороды    4
# 783                          Акустические системы    5

# %%
df.to_csv('csv/hi_tech_test_'+dt.datetime.now().strftime('%Y_%m_%d')+'.csv', index=False)

# %%
dt.datetime.now().strftime('%Y_%m_%d')

# %%
dt.date.today().isoformat()

# %%
stop

# %%
tqdm.pandas() 
df[['тир_юности_14а','тир_25_октября_69','бенд_спортивная_5','бенд_советская_5','бенд_советская_8','слободзея','днестровск',
   'первомайск','григ_кмаркса_181а','григ_кмаркса_172','дубоссары','рыбн_вальченко_43','рыбн_кирова_135','каменка',
   '_category','_subcategory','_group','len']] = df['url'].apply(xxx)
