# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs
import re
from tqdm.notebook import trange, tqdm
from tqdm.gui import tqdm as tqdm_gui
from IPython.display import display
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dft = pd.read_csv('csv/tiraet_final_2024_06_23.csv')

# %%
dft.head(2)
# Out:
#                                                  url     id     _category  \
# 0  https://tiraet.com/catalog/avtojelektronika/av...  78604  T_автотовары
# 1  https://tiraet.com/catalog/avtojelektronika/av...  78235  T_автотовары
#
#       _subcategory           _group    brend  \
# 0  T_автомагнитола  T_автомагнитола   sencor
# 1  T_автомагнитола  T_автомагнитола  kenwood
#
#                                                title        date   price  \
# 0  Автомагнитола Sencor SCT 3018MR (FM/AM, CD, MP...  2024-06-23   660.0
# 1  Автомагнитола Kenwood KDC-130UG (FM/AM, MP3/WA...  2024-06-23  1419.0
#
#    old_price  action_sale  sale group_prise  dif_price availability  \
# 0        NaN            0   NaN      бюджет   3.331818         Мало
# 1        NaN            0   NaN    стандарт   3.331818         Мало
#
#    count_group  activ_count_group  error_group  tir
# 0            6                  6            0    1
# 1            6                  6            0    1

# %%
dfh = pd.read_csv('csv/hi_tech_final_2024_06_23.csv')

# %%
dfh.head(2)
# Out:
#                                                  url           id  \
# 0  https://hi-tech.md/bytovaya-tehnika/klimatiche...  Т-000078544
# 1  https://hi-tech.md/bytovaya-tehnika/aksessuary...  Т-000056675
#
#            _category                             _subcategory  \
# 0            H_акция  H_рассрочка_12_месяцев___без_переплаты!
# 1  H_бытовая_техника  H_аксессуары_для_мелкой_бытовой_техники
#
#                                     _group       brend  \
# 0  H_рассрочка_12_месяцев___без_переплаты!  electrolux
# 1            H_аксессуары_для_зубных_щеток   panasonic
#
#                                              title        date   price  \
# 0         кондиционер Electrolux EACS-07HAT/N3_21Y  2024-06-23  3999.0
# 1  насадка д/Зубная щетка Panasonic EW0940W830 2шт  2024-06-23    34.0
#
#    old_price  action_sale  sale group_prise  dif_price availability  \
# 0        NaN            0   NaN    стандарт   1.000000    В наличии
# 1       68.0            1  50.0      бюджет   2.764706    В наличии
#
#    count_group  activ_count_group  error_group  tir
# 0            1                  1            0    0
# 1            7                  7            0    0

# %%
df = pd.concat([dfh, dft], ignore_index=True)

# %%
df.to_csv('csv/hay_tir.csv', index=False)

# %%
df[df['_group']=='смартфоны']
# Out:
# Empty DataFrame
# Columns: [url, id, _category, _subcategory, _group, brend, title, date, price, old_price, action_sale, sale, group_prise, dif_price, availability, count_group, activ_count_group, error_group, tir]
# Index: []
